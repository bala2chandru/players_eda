# %%
# Cell 1: Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Cell 2: Load data
df = pd.read_csv(r"D:\Players\players.csv")
df.head()

# %%
df.info()

# %%
df.isna().sum()

# %%
df.describe()

# %%
df.to_csv("players_cleaned.csv", index=False)
